# %%
# !pip install transformers
# !pip install accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
from transformers import pipeline

# %%
dolly_llm = pipeline(model="databricks/dolly-v2-3b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto")
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/databricks/dolly-v2-3b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# ...

# %%
dolly_llm.predict("What is the name of President of Pakistan")
# Out:
# [{'generated_text': 'Mashal Khan'}]

# %%
dolly_llm.predict("What is the name of Prime Minister of Pakistan")
# Out:
# [{'generated_text': 'Muhammad Ali Jinnah'}]

# %%
dolly_llm.predict("At which date Pakistan get it's independence")
# Out:
# [{'generated_text': 'November 20th, 1947'}]

# %%
dolly_llm.predict("What is the name of Prime Minister of India")
# Out:
# [{'generated_text': 'Manmohan Singh'}]

# %%
Reviews = [
    """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.

I’ve stayed at many hotels in South Beach/Miami and they’re in a league of their own.	""",
"""There are not enough words to explain the sumptuousness and comfortable elegance you are treated to as a guest at Faena. Their holistic approach to relaxation and community is in paralleled. While every area was wonderful, standouts were Los Fuegos and the Spa. Their staff is magnificent and know how to care for your every whim. Thank you Solange for the welcome and checking!
We will be back""",
"""I went for the Burlesque show which was absolutely amazing. The service was top tier. My bartender was Patty, my drinks were great, one of the best whiskey sours I've had. My server Tatiana was awesome, so sweet and attentive. I highly recommend the show if you get a chance and ask for Patty at the bar""",
"""Dana at Gitano made the night magical! He makes me want to fly to Miami from Chicago for dinner so he can be my server! The hotel is smart to have Dana as a brand ambassador! Well done Faena Hotel for this!""",
"""I would like to give our very very heartfelt thanks to Mr. Raúl Díaz, the Reservations Supervisor ! He was just so helpful and kind ! He just did an amazing Service ! So when ever you planning to go to Miami you have to stay at the Faena Miami and have to get in contact with Mr. Díaz !""",
"""I have to create time to come write this review. First, I have to say how amazing Sophia in the reservations department was. She was very patient with me and my guests in helping me book the correct room for their stay. the Emerson Family loves her and speaks really highly of her. the Faena Hotel will always be my #1 recommendation hotel for Miami. everyone was very helpful and professional.
Stephanie-travel Luxury""",
"""Faena is over-rated.

It would be a 3 star review if it were a 4 star $500 a night type place. But given the price point (we paid $1600/night for our room) and 5 star rating, I am giving it 2. There are much better options for the price point and 5 star category in this location, in my experience (have stayed in miami beach multiple times).

To start with the positive: The services is really good/attentive, the grounds (not rooms) and restaurants are cool/flashy/sceney, and the pool/grounds are solid (not the best in miami). It is popular for the restaurants and cool designs on the grounds and well trained staff. However overall I think there are much better luxury options in miami beach / south beach for an actual stay, if you care more about quality of rooms/actual property, location, and pool.

Issues: 1) the rooms are not that nice. We booked a junior king suite partial ocean view room for $1600/night. The room felt like 4 star vegas with no view. Low ceilings, bones and finishing quality mediocre, cool design touches but overall not 5 star room bones. 2) the hotel is right next to another taller / bigger building that is pretty close, so 95% of the view was blocked/looking directly at that building. We were on the north side which is where half the rooms of the type we booked are, maybe the other side is better. We didnt feel like we were on the beach despite the price and description of the room, you could not see ocean unless standing at an extreme angle to the window. We asked for an upgrade because we thought the description was misleading; we were told this was normal / how the rooms were, and would have to pay significantly more to upgrade. 3) location: it isnt that close to nice restaurants other than the ones at the hotel, which are good, but there isnt much to do around the actual hotel. Options are stay on the grounds or get a 20 minute uber. Not walkable.

Overall I would go here for dinner / drinks and stay somewhere else. One hotel (better all around, most similar from a luxury standpoint but better luxury IMO), Standard (better vibe, better pool, not as luxury, but cooler, and better location), and fountainebleau (better resort-like if that is what you want, faena is kind of resort like) are all better options in my experience. All have better views/pool, and the One and Standard are notably better locations (especially the standard; One is closer / more walkable. The FB is even further/worse location but if you dont want to leave it is better than Faena). I think Faena gets the strong reviews more from the service (which is great and which does make people want to reciprocate with a good review) and the restaurants (they are cool but you dont need to stay here to eat here). And the unique designs/art. But actual rooms, views, location all mediocre, pool etc. fine but not standout.""",
"""The service at the Faena is exceptional. From check in with Sebastian, to the door men at the Jazz lounge, to the cleaning personnel (room 713, you were amazing!)- these folks were a delight. I am pregnant right now, and found out the gender of my baby while staying at the property- Shout out to Vanina, Rosa R. And Lylda P. For helping me plan the most EPIC gender reveal for my husband in the garden behind the mammoth and for helping us capture the day with photos! You all are rockstars! It really made the trip so special. Cannot thank you enough!""",
]

# %%
for review in Reviews:
  print("Review is:", review)
  print(dolly_llm.predict(f"Given the following Hotel Review: {review}, Extract as many facts from it as you can. Return a Bulleted list")[0]['generated_text'])
# Out:
# Review is: Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.
#
# I’ve stayed at many hotels in South Beach/Miami and they’re in a league of their own.
# ...

# %%
review = """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service."""


print(dolly_llm.predict(f"Given the following Hotel Review: {review}, Extract as many facts from it as you can. Return a Bulleted list")[0]['generated_text'])
# Out:
# Hotel Name: Hands down my absolute favorite hotel in South Beach - there’s no place I’d rather stay.
# I’ve been back four times in the past six months - each experience is better than the last and I look forward to coming back.
# As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and goes out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.
# Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.

# %%
review = """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service."""


print(dolly_llm.predict(f"Given the following sentence: {review}, Extract as many Questions and Answers from it as you can. \n Return {{Question # }}\n {{Answer}}")[0]['generated_text'])
# Out:
# Questions:
#
# 1. Why is the hotel hands down best?
#
# The hotel is hands down best because of Petar, the front desk agent. Each time I come back, Petar ensures that my stay is exceptional and I never have to worry.
#
# 2. As impressive as the hotel is, the team of people are what make each stay exceptional.
#
# As impressive as the hotel is, the team of people are what make each stay exceptional. The team includes excellent front desk agents such as Petar.

# %%
review = """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service."""


print(dolly_llm.predict(f"Given the following sentence: {review}, Extract as many Questions and Answers from it as you can. Do not use any Pronoun, instead be very specefic for each question. \n Return {{Question # }}\n {{Answer}}")[0]['generated_text'])
# Out:
# Petar, how are you?
# I'm good thanks.
# How are you?
# Great! I’m thrilled to be in this position and I couldn’t be happier.
# Where are you from?
# I'm from Croatia.
# That explains a lot - I’m so happy to hear you are from Croatia. When did you arrive in the US?
# Just 2 years ago.
# That explains a lot! What brings you to South Beach?
# I love South Beach. As soon as I arrived, I started looking for a place and I fell in love with this hotel. I couldn’t be happier here.
# That’s wonderful! How long do you think you will be staying in South Beach?
# I hope to be staying for a long time.
# That’s great to hear! What makes this hotel special?
# As much as I love the hotel, it’s Petar that makes it so special. He goes above and beyond to provide excellent service and makes me feel so welcome and comfortable each and every time.
# That’s really impressive. What’s his name?
# Petar.
# Petar, that’s a beautiful name.
# It is, isn

# %%
review = """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service."""


print(dolly_llm.predict(f"Given the following sentence: {review}, Extract as many Questions and Answers from it as you can. Do not use any Pronouns in Questions. \n Return format {{Question # }}\n {{Answer}}")[0]['generated_text'])
# Out:
# Question # 1
#
# Is the hotel hands down my favorite?
# The hotel is hands down my absolute favorite.
#
# Question # 2
#
# As impressive as the hotel is, the team of people are what make each stay exceptional.
# Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time.
#
# Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.

# %%
review = """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service."""


print(dolly_llm.predict(f"Given the following sentence: {review}, Extract as many Questions and Answers from it as you can. Think of each question as a fact that can be independently evaluated. Do not use any Pronouns in Questions and Answers. \n Return format {{Question # }}\n {{Answer}}")[0]['generated_text'])
# Out:
# Hands down my absolute favorite hotel in South Beach is {SR.Hands down my absolute favorite hotel in South Beach is}. I’ve been back four times in the past six months—each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and Petar goes above and beyond to provide excellent service.

# %%
review = """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service."""


print(dolly_llm.predict(f"You are a Questions and Facts Extractor. Think of each question as a fact that can be independently evaluated from the given sentence. Given the following sentence: Sentence= {review}, Extract as many Questions and thier Answers from it as you can. Do not use any Pronouns in Questions and Answers. \n Return format {{Question # }}\n {{Answer}}")[0]['generated_text'])
# Out:
# As impressive as the hotel is, the team of people are what make each stay exceptional.
#
# Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time.
#
# Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.

# %%
review = """Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service."""


print(dolly_llm.predict(f"You are a Questions and Facts Extractor. Think of each question as a fact that can be independently evaluated using the given input sentence. Given the following sentence: Sentence= {review}, Extract as many Questions that can be independently verified with the given Answers from it as you can. \n Return format:\n {{Question # }}\n {{Answer}}")[0]['generated_text'])
# Out:
# My favorite hotel in South Beach is:
# Hilton everytime
# Hilton everytime
# Hilton everytime
# Petar always makes my stay wonderful
# Petar always makes my stay wonderful

# %%
Reviews
# Out:
# ['Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.\n\nI’ve stayed at many hotels in South Beach/Miami and they’re in a league of their own.\t',
# ...

# %%
import pandas as pd

# %%
print(dolly_llm.predict(f"""Given the following Reviews for a hotels
Reviews={Reviews} 
and the following questions
Q1. Fine me a restaurant with a specific style of interior design or decor?
Q2. Which Resturants Are good for any specific occasions or celebrations?
Q3. Which restaurant is known for using fresh, locally sourced ingredients?
Q4. Which restaurant have a good selection of vegetarian or vegan options?
Q5. Which restaurant have a good selection of beverages?

Answer the above questions and find me the best resturant. Return format {{Question #}} {{Answer #}}
""")[0]['generated_text'])
# Out:
# 1. Salad or Steak? Salad. I love a healthy salad but when I'm in the mood for an indulgent meal I go straight to the steak menu
# 2. Simple but Modern? The Mercer in mid beach - it looks amazing but you will want to dress it up with something...this blue table cloth? Or you can go for italian or fish bowls and feel right at home
# 3. Good for weekend brunch? Karibu - the croissants are to die for, and the croquette were delicious
# 4. Go for Italian? Osteria Francescana is where you want to go for Traditional Italian - if you want to go Modern or Fusion - make a beeline for Pasquale's
# 5.  Mid Beach Spa? The Spa at the Faena is so luxurious you will want to have a hard time placing the beauty treatments on a traditional spa scale. I would suggest a trip to Mirae for your much needed deep tissue work.
# and the following questions
# Q1. Salad or Steak? Salad. I love a healthy salad but when I'm in the mood for an indulgent meal I go straight to the steak menu
# ...

# %%
print(dolly_llm.predict(f"""Given the following Reviews for a hotels
Reviews={Reviews} 
and the following questions
Q1. Fine me a restaurant with a specific style of interior design or decor?
Q2. Which Resturants Are good for any specific occasions or celebrations?
Q3. Which restaurant is known for using fresh, locally sourced ingredients?
Q4. Which restaurant have a good selection of vegetarian or vegan options?
Q5. Which restaurant have a good selection of beverages?

Answer the above questions and find me the best resturant. Return format {{Question #}} {{Resturant Name #}}
""")[0]['generated_text'])
# Out:
# Resturant: {Question #} {Resturant Name #}
# 1. A restaurant with a specific style of interior design or decor: Starbucks
#  2. Which Resturants are good for any specific occasions or celebrations?
#   1. Italian
#   2. Mediterranean
#   3. South Beach
#   4. Cuban
#   5. French
#  2.  Resturant is known for using fresh, locally sourced ingredients: Naturalia
#  1. Italian: Al Cervelli
#  2. Mediterranean: Sidamo
#  3. South Beach: Zoe
#  4. Cuban: Cafe Du Monde
#  5. French: Daniel
#
# Answer: {Restaurant Name #}

# %%
print(' '.join(["\n Resturant # " + str(i+1) + " " + element for i, element in enumerate(Reviews)]).strip())
# Out:
# Resturant # 1 Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.
#
# I’ve stayed at many hotels in South Beach/Miami and they’re in a league of their own.
# ...

# %%
print("""Given the following Reviews for a hotels
Reviews={} 
and the following questions
Q1. Which restaurant is best with a specific style of interior design or decor?
Q2. Which Resturants is best for any specific occasions or celebrations?
Q3. Which restaurant is best for using fresh, locally sourced ingredients?
Q4. Which restaurant is best for a good selection of vegetarian or vegan options?
Q5. Which restaurant is best for a good selection of beverages?

Answer the above questions and find me the best resturant. Return format {{Question #}} {{Resturant Number #}}
""".format(' '.join(['\n Resturant # ' + str(i+1) + ' ' + element for i, element in enumerate(Reviews)]).strip()))
# Out:
# Given the following Reviews for a hotels
# Reviews=Resturant # 1 Hands down my absolute favorite hotel in South Beach—there’s no place I’d rather stay. I’ve been back four times in the past six months –each experience is better than the last and I always look forward to coming back. As impressive as the hotel is, the team of people are what make each stay exceptional. Everyone is so friendly and they go out of their way to ensure that I have a perfect stay every single time. Petar in particular always ensures that my stay is wonderful every time and gives me total peace of mind every time I stay there - I never have to worry about a thing and he goes above and beyond to provide excellent service.
#
# I’ve stayed at many hotels in South Beach/Miami and they’re in a league of their own.
# ...

# %%
print(dolly_llm.predict("""Given the following Reviews for a hotels
Reviews={} 
and the following questions
Q1. Which restaurant is best with a specific style of interior design or decor?
Q2. Which Resturants is best for any specific occasions or celebrations?
Q3. Which restaurant is best for using fresh, locally sourced ingredients?
Q4. Which restaurant is best for a good selection of vegetarian or vegan options?
Q5. Which restaurant is best for a good selection of beverages?

Answer the above questions and find me the best resturant. Return format {{Question #}} {{Resturant Number #}}
""".format(' '.join(['\n Resturant # ' + str(i+1) + ' ' + element for i, element in enumerate(Reviews)]).strip()))[0]['generated_text'])
# Out:
# I will be happy to help you with the following questions:
# Which restaurants is best for a good selection of vegetarian or vegan options?
# The Faena has the following vegetarian/vegan restaurants:
# - Casa Azul
# - The Exchange
# - La Bottega
# - Marques Logistics
# - Olivo
# - Tristan Dodge
# - Walter (PUB)
# - The Launch Pad
# - Faena Social Club (FSC)
# - The Conservatory
# - Grey St.
# - Trovillion (restaurant within the hotel)
# - Basque Room
# - Bvlgars
# - Vlad the Conquerer
# - One of One
# - Diva
# - Spice Room
# - Spice Market
# - DeKooning
# - Backbar
# - Sabor
# - Guastalla
# - Desnudo
# - Citrus
# - Zanzibar
# - Venus
# - Orient Express
# - The Blue Parrot
# - La Stanza
# - Cocina Focacceria
# - Tamares
# - Alma Mia
# - Afroamericanas.

# %%
prompt = """Given the following Reviews for a hotels
Reviews={} 
and the following questions
Q1. Which restaurant is best with a specific style of interior design or decor?
Q2. Which Resturants is best for any specific occasions or celebrations?
Q3. Which restaurant is best for using fresh, locally sourced ingredients?
Q4. Which restaurant is best for a good selection of vegetarian or vegan options?
Q5. Which restaurant is best for a good selection of beverages?

Answer the above questions and find me the best resturant. Return format {{Question # <>}} Answer: {{Resturant Number #}}
""".format(' '.join(['\n Resturant # ' + str(i+1) + ' ' + element for i, element in enumerate(Reviews)]).strip())


print(dolly_llm.predict(prompt)[0]['generated_text'])
# Out:
# The following restaurants are best for specific interior design or decor:
# Los Fuegos
# Vintage Cigars
# Jolie du Latour
# El Born
# Grand Faloon
# Ana Rey O
# Faena has good interior design, but not best. Each area is unique, but the overall experience is consistent and good.

# %% [markdown]
# # Falcon LLM

# %%
# !pip install transformers
# !pip install accelerate
# !pip install einops
# !pip install xformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 83.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.6 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 10.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.5 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 8.4 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-7b"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - configuration_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - modelling_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
import pandas as pd


url = "https://raw.githubusercontent.com/hamzafarooq/hotelfinder/main/Hotel%20New%20York%20Combined.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    Field_1                                      hotel_name  \
# 0       25  Four Points by Sheraton Manhattan Midtown West
# 1       25  Four Points by Sheraton Manhattan Midtown West
# 2       25  Four Points by Sheraton Manhattan Midtown West
# 3       25  Four Points by Sheraton Manhattan Midtown West
# 4       25  Four Points by Sheraton Manhattan Midtown West
#
#                                                  url  locality  reviews  \
# 0  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 1  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 2  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 3  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 4  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
#
#    tripadvisor_rating    checkIn   checkOut price_per_night booking_provider  \
# 0                 NaN  10/1/2019  10/5/2019             NaN   FourPoints.com
# ...

# %%
df['hotel_name']
# Out:
# 0       Four Points by Sheraton Manhattan Midtown West
# 1       Four Points by Sheraton Manhattan Midtown West
# 2       Four Points by Sheraton Manhattan Midtown West
# 3       Four Points by Sheraton Manhattan Midtown West
# 4       Four Points by Sheraton Manhattan Midtown West
#                              ...
# 1754         Hotel Giraffe by Library Hotel Collection
# 1755         Hotel Giraffe by Library Hotel Collection
# 1756         Hotel Giraffe by Library Hotel Collection
# 1757         Hotel Giraffe by Library Hotel Collection
# 1758         Hotel Giraffe by Library Hotel Collection
# Name: hotel_name, Length: 1759, dtype: object

# %%
df.groupby('hotel_name').count()
# Out:
#                                                     Field_1  url  locality  \
# hotel_name
# 255West Guesthouse                                       38   38        38
# Andaz Wall Street                                        54   54        54
# Artezen Hotel                                            37   37        37
# Carvi NYC                                                54   54        54
# Cassa Hotel Times Square                                 54   54        54
# Colonial House Inn                                       54   54        54
# Crowne Plaza Times Square Manhattan                      54   54        54
# Dream Midtown                                            54   54        54
# Four Points by Sheraton Manhattan Midtown West           54   54        54
# Gansevoort Meatpacking NYC                               54   54        54
# Hilton Garden Inn Times Square                           54   54        54
# ...

# %%
for hotel_name, row in df.groupby('hotel_name').count().iterrows():
    name = hotel_name
    number_of_reviews = row['reviews']
    print(f"Hotel Name: {name}, Number of Reviews: {number_of_reviews}")
# Out:
# Hotel Name: 255West Guesthouse, Number of Reviews: 38
# Hotel Name: Andaz Wall Street, Number of Reviews: 54
# Hotel Name: Artezen Hotel, Number of Reviews: 37
# Hotel Name: Carvi NYC, Number of Reviews: 54
# Hotel Name: Cassa Hotel Times Square, Number of Reviews: 54
# Hotel Name: Colonial House Inn, Number of Reviews: 54
# Hotel Name: Crowne Plaza Times Square Manhattan, Number of Reviews: 54
# Hotel Name: Dream Midtown, Number of Reviews: 54
# Hotel Name: Four Points by Sheraton Manhattan Midtown West, Number of Reviews: 54
# Hotel Name: Gansevoort Meatpacking NYC, Number of Reviews: 54
# Hotel Name: Hilton Garden Inn Times Square, Number of Reviews: 54
# Hotel Name: Hotel Giraffe by Library Hotel Collection, Number of Reviews: 54
# Hotel Name: Hotel Mimosa New York, Number of Reviews: 54
# Hotel Name: IBEROSTAR 70 Park Avenue Hotel, Number of Reviews: 54
# Hotel Name: InterContinental New York Times Square, Number of Reviews: 54
# ...

# %%
print(df.head())
# Out:
#    Field_1                                      hotel_name  \
# 0       25  Four Points by Sheraton Manhattan Midtown West
# 1       25  Four Points by Sheraton Manhattan Midtown West
# 2       25  Four Points by Sheraton Manhattan Midtown West
# 3       25  Four Points by Sheraton Manhattan Midtown West
# 4       25  Four Points by Sheraton Manhattan Midtown West
#
#                                                  url  locality  reviews  \
# 0  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 1  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 2  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 3  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
# 4  http://www.tripadvisor.com/Hotel_Review-g60763...  New York      207
#
#    tripadvisor_rating    checkIn   checkOut price_per_night booking_provider  \
# 0                 NaN  10/1/2019  10/5/2019             NaN   FourPoints.com
# ...

# %%
for hotel_name, group in df.groupby('hotel_name'):
    name = hotel_name
    number_of_reviews = group['reviews'].iloc[0]
    reviews = group['review_body']
    
    review_string = f"Hotel Name: {name}, Number of Reviews: {number_of_reviews}\n"
    for i, review in enumerate(reviews, start=1):
        review_string += f"Review {i}: {review}\n"
    
    # Print or store the review string
    print(review_string)
# Out:
# Hotel Name: 255West Guesthouse, Number of Reviews: 75
# Review 1: staying in the 255 west guesthouse brownstone while visiting new york was like a dream come true! the decor was lovely and james was a gracious host. i was attending a reading institute at columbia teachers college and it was a pleasant 25 minute walk to
# Review 2: This place was a really fun place to stay. I booked the Lily room and enjoyed everything, especially the awesome shower. It was clean, comfortable, and a short walk to where I needed to go for work. I would book again.
# Review 3: Very nice experience. We spent 3 nights in Calliope room on 2nd floor. Room was clean, nicely decorated and perfect for our needs. Nice change from hotel vibe. Had a small refrigerator. James the owner was available and responsive to us.Would stay again.
# ...

# %%
# Complete reviews for 1 hotel togethar goes out of context length, so we need to strip the input

for hotel_name, group in df.groupby('hotel_name'):
    name = hotel_name
    number_of_reviews = group['reviews'].iloc[0]
    reviews = group['review_body']
    
    review_string = f"Hotel Name: {name}, Number of Reviews: {number_of_reviews}\n"
    print(f"Review for {review_string}")
    for i, review in enumerate(reviews, start=1):
        review_string += f"Review {i}: {review}\n"
    
    # Print or store the review string
    print(dolly_llm.predict("""Given the following Reviews for Hotels in the format
<Hotel Details>
<Review: i>
<Review: i+1>
...
{reviews}
Your job is to think of some Questions that are available in the above Hotel Details. These questions can be those which are what a person can think of when choosing a hotel
Some of the example questions are:
1. What is the location of the <hotel name>? 
2. What are the amenities and facilities offered by the <hotel name>?
3. Is breakfast included in the room rate at <hotel name>?""".format(reviews=review_string)))
# Out:
# Review for Hotel Name: 255West Guesthouse, Number of Reviews: 75
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:12                                                                             │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:881 in predict            │
# │                                                                                                  │
# │    878 │   │   """                                                                               │
# │    879 │   │   Scikit / Keras interface to transformers' pipelines. This method will forward to  │
# │    880 │   │   """                                                                               │
# │ ❱  881 │   │   return self(X)                                                                    │
# ...

# %%
for hotel_name, group in df.groupby('hotel_name'):
    name = hotel_name
    number_of_reviews = group['reviews'].iloc[0]
    reviews = group['review_body']
    
    review_string = f"Hotel Name: {name}, Number of Reviews: {number_of_reviews}\n"
    print(f"Review for {review_string}")
    for i, review in enumerate(reviews, start=1):
        review_string += f"Review {i}: {review}\n"
    
    # Print or store the review string
    print(dolly_llm.predict("""Given the following Reviews for Hotels in the format
<Hotel Details>
<Review: i>
<Review: i+1>
...
{reviews}
Your job is to think of some Questions that are available in the above Hotel Details. These questions can be those which are what a person can think of when choosing a hotel
Some of the example questions are:
1. What is the location of the <hotel name>? 
2. What are the amenities and facilities offered by the <hotel name>?
3. Is breakfast included in the room rate at <hotel name>?

Return format: <question> Answer: <>""".format(reviews=review_string[:3000])))
# Out:
# Review for Hotel Name: 255West Guesthouse, Number of Reviews: 75
#
# [{'generated_text': 'What is the location of the 255West Guesthouse, Number of Reviews: 75\n<Rest of question is left unformatted>'}]
# Review for Hotel Name: Andaz Wall Street, Number of Reviews: 3395
#
# [{'generated_text': '1. The location of Andaz Wall Street is 23 Battery Street, New York, NY 10004. \n2. The facilities and amenities offered by the Andaz Wall Street are, the rooms are big, very clean and modern,the AC in the room is working good, the location is very near the Wall street and the pier and the Staten Island. There is a subway station nearby. \n3.Breakfast is not included in the room rate.'}]
# Review for Hotel Name: Artezen Hotel, Number of Reviews: 67
#
# ...
